# %%
from google.colab import drive
drive.mount("./drive")

path_prefix = "./drive/My Drive"
# Out:
# Mounted at ./drive

# %%
from google.colab import drive
from os.path import join
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np

drive.mount('/content/drive')
fname1 = "mobile_train.csv"
fname2 = "mobile_test.csv"
dtrain = pd.read_csv(join(path_prefix, fname1))
dtest = pd.read_csv(join(path_prefix, fname2))
dtrain.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# ...

# %%
dtest.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
dtrain.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
column_names = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt',
                'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']
x = dtrain[column_names]
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y=dtrain[['price_range']]
y
# Out:
#       price_range
# 0               1
# 1               2
# 2               2
# 3               2
# 4               1
# ...           ...
# 1995            0
# 1996            2
# 1997            3
# 1998            0
# 1999            3
#
# [2000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# Assuming your data is stored in 'x' (features) and 'y' (target variable)

# Split the data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = tf.keras.Sequential([
   keras.layers.Dense(125, activation='relu', input_shape=(20,)),

   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),
   keras.layers.Dense(125, activation='relu'),






   keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')


model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_28 (Dense)            (None, 125)               2625
#
#  dense_29 (Dense)            (None, 125)               15750
#
#  dense_30 (Dense)            (None, 125)               15750
#
#  dense_31 (Dense)            (None, 125)               15750
#
#  dense_32 (Dense)            (None, 125)               15750
#
#  dense_33 (Dense)            (None, 125)               15750
#
#  dense_34 (Dense)            (None, 125)               15750
#
#  dense_35 (Dense)            (None, 125)               15750
#
#  dense_36 (Dense)            (None, 125)               15750
#
#  dense_37 (Dense)            (None, 4)                 504
#
# ...
# Total params: 129,129
# Trainable params: 129,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=500)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 2s 4ms/step - loss: 3.1397
# Epoch 2/500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.9648
# Epoch 3/500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8835
# Epoch 4/500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.8740
# Epoch 5/500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.8291
# Epoch 6/500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7876
# Epoch 7/500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.7184
# Epoch 8/500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.7058
# Epoch 9/500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6940
# Epoch 10/500
# 50/50 [==============================] - 0s 8ms/step - loss: 0.6900
# Epoch 11/500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6972
# Epoch 12/500
# ...

# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score

# Get the test data


# Predict the labels for the test data
y_pred = model.predict(x_test)

# Convert the predicted probabilities to binary labels (0 or 1)

y_pred_classes = np.argmax(y_pred, axis=1)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred_classes)

print('Accuracy:', accuracy)
# Out:
# 13/13 [==============================] - 0s 3ms/step
# Accuracy: 0.9475
